# %%
# prerequisite package imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

from solutions_univ import scales_solution_1, scales_solution_2

# %% [markdown]
# Once again, we make use of the Pokémon data for this exercise.

# %%
pokemon = pd.read_csv('./data/pokemon.csv')
pokemon.head()
# Out:
#    id     species  generation_id  height  weight  base_experience type_1  \
# 0   1   bulbasaur              1     0.7     6.9               64  grass
# 1   2     ivysaur              1     1.0    13.0              142  grass
# 2   3    venusaur              1     2.0   100.0              236  grass
# 3   4  charmander              1     0.6     8.5               62   fire
# 4   5  charmeleon              1     1.1    19.0              142   fire
#
#    type_2  hp  attack  defense  speed  special-attack  special-defense
# 0  poison  45      49       49     45              65               65
# 1  poison  60      62       63     60              80               80
# 2  poison  80      82       83     80             100              100
# 3     NaN  39      52       43     65              60               50
# 4     NaN  58      64       58     80              80               65

# %% [markdown]
# **Task 1**: There are also variables in the dataset that don't have anything to do with the game mechanics, and are just there for flavor. Try plotting the distribution of Pokémon heights (given in meters). For this exercise, experiment with different axis limits as well as bin widths to see what gives the clearest view of the data.

# %%
adjust = 0.3
data = pokemon['height']
bins = np.arange(0, data.max() + adjust, adjust)
print('Bin count', len(bins))
sb.distplot(data, bins=bins)
plt.show()
# Out:
# Bin count 50

# %%
# Select specific range (zoom into [0, 6])
adjust = 0.25
data = pokemon['height']
data = data[data <= 6]
bins = np.arange(0, data.max() + adjust, adjust)
print('Only for data with height <= 6')
print('Bin count', len(bins))
sb.distplot(data, bins=bins)
plt.show()
# Out:
# Only for data with height <= 6
# Bin count 25

# %%
# run this cell to check your work against ours
scales_solution_1()
# Out:
# There's a very long tail of Pokemon heights. Here, I've focused in on Pokemon of height 6 meters or less, so that I can use a smaller bin size to get a more detailed look at the main data distribution.

# %% [markdown]
# **Task 2**: In this task, you should plot the distribution of Pokémon weights (given in kilograms). Due to the very large range of values taken, you will probably want to perform an _axis transformation_ as part of your visualization workflow.

# %%
pokemon['weight'].describe()
# Out:
# count    807.000000
# mean      61.771128
# std      111.519355
# min        0.100000
# 25%        9.000000
# 50%       27.000000
# 75%       63.000000
# max      999.900000
# Name: weight, dtype: float64

# %%
data = pokemon['weight']
sb.distplot(data)
plt.show()

# %%
# Apply log transform
adjust = 0.1
data = np.log(pokemon['weight'])
bins = np.arange(data.min(), data.max() + adjust, adjust)
print(data.describe())
sb.distplot(data)
plt.show()
# Out:
# count    807.000000
# mean       3.141569
# std        1.544962
# min       -2.302585
# 25%        2.197225
# 50%        3.295837
# 75%        4.143135
# max        6.907655
# Name: weight, dtype: float64

# %%
# Adjust xticks
adjust = 0.01
data = np.log(pokemon['weight'])
bins = np.arange(data.min(), data.max() + adjust, adjust)
print('Bin count', len(bins))
sb.distplot(data)
plt.show()
# Out:
# Bin count 923

# %%
# run this cell to check your work against ours
scales_solution_2()
# Out:
# Since Pokemon weights are so skewed, I used a log transformation on the x-axis. Bin edges are in increments of 0.1 powers of ten, with custom tick marks to demonstrate the log scaling.
